# %%
# %run ../../v4/misc/data_access.py
# Out:
# get_project_folder(): /Users/raminsoleymani/git/ECO/
# get_data_folder(): /Users/raminsoleymani/git/ECO/data/
# get_model_folder(): /Users/raminsoleymani/git/ECO/models/

# %%
import codecs
import json
from collections import Counter
import operator
import pandas as pd
from IPython.core.display import display, HTML

def read_json_file(file_name):
    with codecs.open(file_name,encoding='utf-8') as fin:
        return json.loads(fin.read())
    
# def write_dict_to_file(file_name,dict_):
#     with codecs.open(file_name,'w', encoding='utf-8') as fout:
#         fout.write(json.dumps(dict_, indent=2, ensure_ascii=False))


def get_accum_file_sizes(doc_list, get_sorted = True):
    authors_accum_file_size = {}
    author_set = get_author_set(doc_list)
    for author in author_set:
        authors_accum_file_size[author] = sum([doc["file_size"] for doc in doc_list if doc["author_name"] == author])
    if not get_sorted:
        return authors_accum_file_size
    sorted_sizes = sorted(authors_accum_file_size.items(), key=operator.itemgetter(1),reverse=True) 
    return sorted_sizes
    
def get_author_counter(doc_list):
    return Counter([text["author_name"] for text in doc_list])

def get_author_set(doc_list):
    author_counter = get_author_counter(doc_list)
    del author_counter["No Author"]
    return list(set(dict(author_counter)))
    
def log_JSON_Analysis(log_json, n = 30):
    col = read_json_file(log_json)['file_descriptors']
    doc_list = list(col.values())
    print("Number of Documentes\n",len(col))
    print()

    author_counter = get_author_counter(doc_list)
    author_set = get_author_set(doc_list)
    
    print("Number of authors\n",len(author_set))
    print()
        
    most_common = {ac:author_counter[ac] for ac in author_counter if author_counter[ac] > 10}
    print("Authors with more then 10 documents (", len(most_common),')')

    print(Counter(most_common))
    print()   
    
    print("Top %s Authors with accumulated file sizes:" % n)
    print()
    
    sorted_sizes = get_accum_file_sizes(doc_list)
    top_n = sorted_sizes[:n]
    row_list = []
    for a in top_n:
        new_row = {}
        new_row['name'] = a[0]
        new_row['size'] = a[1]
        new_row['docs'] = author_counter[a[0]]
        row_list.append(new_row)
        
    top_n_df = pd.DataFrame(row_list,columns=['name','docs','size'])  
    display(top_n_df)
    

log_JSON_Analysis('log-final.json', 50)
# Out:
# Number of Documentes
#  4741
#
# Number of authors
#  2554
#
# Authors with more then 10 documents ( 39 )
# Counter({'No Author': 214, 'Chomsky,Noam': 73, 'October': 67, 'Bogost,Ian': 39, 'Hayles,Katherine': 36, 'Bakunin,Mikhail': 35, 'Nader,Laura': 35, 'Goldman,Emma': 34, 'Black,Bob': 31, 'Zerzan,John': 31, 'Kropotkin,Peter': 30, 'Malatesta,Errico': 30, 'Garland,David': 24, 'Thacker,Eugene': 23, 'Foster,Roger': 19, 'Bookchin,Murray': 19, 'Agrawal,Nelson': 19, 'Galloway,Alexander': 18, 'Churchill,Ward': 17, 'Krauss,Rosalind': 17, 'Harvey,Adrian': 17, 'Foster,Hal': 15, 'Bonanno,Alfredo': 15, 'Avrich,Paul': 14, 'Magón,Flores': 14, 'Lovink,Geert': 13, 'Home,Stewart': 13, 'De Cleyre': 13, 'Franks,Benjamin': 13, 'Smil,Vaclav': 13, 'Danto,Arthur': 12, 'Valverde,Mariana': 12, 'Berkman,Alexander': 12, 'Mitchell,William': 11, 'Smith,Stephen': 11, 'Cae': 11, 'Newman,James': 11, 'Bell,David': 11, 'Weiss,Allen': 11})
#
# Top 50 Authors with accumulated file sizes:
#                       name  docs     size
# 0                  October    67  6399579
# 1             Goldman,Emma    34  3969364
# 2        Featherstone,Mike     6  3404807
# 3                   Fieser     1  3363083
# 4             Chomsky,Noam    73  3349165
# 5                 Sullivan     5  2882483
# 6             Lovink,Geert    13  2819149
# 7    Anttiroiko,Ari Veikko     1  2799658
# 8            Smith,Stephen    11  2693772
# 9   Charles Sanders Pierce     1  2556000
# 10         Lessig,Lawrence     6  2490135
# 11       Chemerinsky,Erwin     2  2440437
# 12                  Cutler     1  2161596
# 13               Philander     1  2115106
# 14             Smil,Vaclav    13  2071748
# 15            Elkins,James    10  2014350
# 16            Lawson,Bryan     6  2009663
# 17             Daly,Herman     4  1962590
# 18          Marshall,Peter     2  1920920
# 19       Krech Iii,Shepard     2  1820464
# 20            Shaw,Malcolm     5  1820195
# 21         Demeny,Mcnicoll     1  1806941
# 22              Johnson,Cb     6  1725486
# 23        Castells,Haraway     9  1673842
# 24       Berkman,Alexander    12  1644056
# 25           Diamond,Jared     5  1643844
# 26          Jensen,Derrick     8  1605418
# 27           Drake,William     2  1583715
# 28              Lewis,Troy     4  1560278
# 29         Kropotkin,Peter    30  1540878
# 30                   Rawls     5  1527332
# 31         Costanza,Robert     3  1471278
# 32            Drahos,Peter     4  1389463
# 33            Ehrlich,Paul     1  1381921
# 34           Biggs,Michael     2  1375866
# 35          Thacker,Eugene    23  1374614
# 36       Jennings,Marianne     1  1322779
# 37          Allaby,Michael     1  1299210
# 38           Henderson,Ann     2  1276188
# 39        Hayles,Katherine    36  1229486
# 40                Nienhuis     2  1220412
# 41          Schubert,Frank     1  1210776
# 42               Reinhardt     1  1207187
# 43         Feather,Sturges     1  1203609
# 44   Pierrehumbert,Raymond     1  1190366
# 45          Wilson,Stephen     3  1172394
# 46                 Sifakis     1  1168676
# 47           Turkle,Sherry     6  1142686
# 48            Foster,Roger    19  1123747
# 49           Feibel,Werner     1  1105828

# %%
import codecs
import json
import os

def read_json_file(file_name):
    with codecs.open(file_name,encoding='utf-8') as fin:
        return json.loads(fin.read())

def merge_docs(author_name,log_file, dest_folder = None,overwrite= False):
    log = read_json_file(log_file)
    author_docs = [doc for doc in list(log['file_descriptors'].values()) if doc['author_name'] == author_name]

    base_folder = get_data_folder() + log["folder_path"] 
    print(base_folder)
    if not os.path.isdir(base_folder):
        print('''Value: "%s" is not set correctly. Cannot find folder:\n%s
        The folder is relative to the project data folder\nBYE''' %("folder_path", base_folder))
        return
    if not dest_folder:
        dest_folder = base_folder + "merged/"
    dest_file = (dest_folder + author_name + '.txt').replace(",","_")
    
    print("Creating:",dest_file)
    
    if not os.path.exists(dest_folder): os.makedirs(dest_folder)
        
    if os.path.isfile(dest_file) and not overwrite:
        print('File %s exists already & overwrite is not set. ending here...' %(dest_file))
        return dest_file
    
    def get_docs_abs_path(doc_dict):
        return base_folder + doc_dict["rel_path"] + doc_dict["file_name"]
    
    file_names = [get_docs_abs_path(doc) for doc in author_docs]
    print('Merging %s files' % len(file_names))
    return dest_file

    
    with codecs.open(dest_file, 'w') as outf:
        for fname in file_names:
            if not os.path.exists(fname):
                print("%s\ndoes not exist. skipping")
                continue
            with open(fname) as inf:
                for line in inf:
                    outf.write(line)
                    
    print("DONE!\nResulting file is a size of %s bytes" % os.stat(dest_file).st_size)


merge_docs('Chomsky,Noam','log-final.json',overwrite=True)
# Out:
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Chomsky_Noam.txt
# Merging 73 files
# '/Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Chomsky_Noam.txt'

# %%
import codecs
from random import random
import os

def split_for_train_test(file_path, destination_folder = None, test_ratio = 0.05, overwrite=False):
        if not destination_folder:
            destination_folder = file_path[:file_path.rindex('.')]+'_SPLIT/'
        print("Splitting %s" % file_path)
        print("Destination folder:",destination_folder)
        
        if not os.path.exists(destination_folder): os.makedirs(destination_folder)
            
        fout_train = destination_folder + 'train.txt'
        fout_test = destination_folder + 'test.txt'
        
        if os.path.exists(fout_train) and not overwrite:
            print("%s exists and overwrite is not set.\nBye" % fout_train)
            return

        if os.path.exists(fout_test) and not overwrite:
            print("%s exists and overwrite is not set. Bye" % fout_test)
            return
            
            
        f_in = codecs.open(file_path, 'r', 'UTF-8')
        f_out_train = codecs.open(fout_train, 'w', 'UTF-8')
        f_out_test = codecs.open(fout_test, 'w', 'UTF-8')

        for line in f_in:
            if random() < test_ratio:
                f_out_test.write(line)
            else:
                f_out_train.write(line)
        print("DONE")

log_file = 'log-final.json'
file_path = get_data_folder() + read_json_file(log_file)["folder_path"] + '/merged/Chomsky_Noam.txt'
split_for_train_test(file_path ,overwrite=True)
# Out:
# Splitting /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3//merged/Chomsky_Noam.txt
# Destination folder: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3//merged/Chomsky_Noam_SPLIT/
# DONE

# %%
### Get the top 30 create their merged texts and split them in train/test

# TOP_N = 30
# def read_json_file(file_name):
#     with codecs.open(file_name,encoding='utf-8') as fin:
#         return json.loads(fin.read())

# log_file = 'log-final.json'
# col = read_json_file(log_file)['file_descriptors']
# doc_list = list(col.values())
    
# sorted_sizes = get_accum_file_sizes(doc_list)
# top_n_names = [author_size_tuple[0] for author_size_tuple in sorted_sizes[:TOP_N]]
# for author in top_n_names:
#     print(author)
#     merge_docs(author,log_file)
# print("ALL DONE")
# Out:
# October
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/October.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/October.txt exists already & overwrite is not set. ending here...
# Goldman,Emma
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Goldman_Emma.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Goldman_Emma.txt exists already & overwrite is not set. ending here...
# Featherstone,Mike
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Featherstone_Mike.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Featherstone_Mike.txt exists already & overwrite is not set. ending here...
# Fieser
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Fieser.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Fieser.txt exists already & overwrite is not set. ending here...
# Chomsky,Noam
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Chomsky_Noam.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Chomsky_Noam.txt exists already & overwrite is not set. ending here...
# Sullivan
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Sullivan.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Sullivan.txt exists already & overwrite is not set. ending here...
# Lovink,Geert
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Lovink_Geert.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Lovink_Geert.txt exists already & overwrite is not set. ending here...
# Anttiroiko,Ari Veikko
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Anttiroiko_Ari Veikko.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Anttiroiko_Ari Veikko.txt exists already & overwrite is not set. ending here...
# Smith,Stephen
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Smith_Stephen.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Smith_Stephen.txt exists already & overwrite is not set. ending here...
# Charles Sanders Pierce
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Charles Sanders Pierce.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Charles Sanders Pierce.txt exists already & overwrite is not set. ending here...
# Lessig,Lawrence
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Lessig_Lawrence.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Lessig_Lawrence.txt exists already & overwrite is not set. ending here...
# Chemerinsky,Erwin
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Chemerinsky_Erwin.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Chemerinsky_Erwin.txt exists already & overwrite is not set. ending here...
# Cutler
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Cutler.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Cutler.txt exists already & overwrite is not set. ending here...
# Philander
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Philander.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Philander.txt exists already & overwrite is not set. ending here...
# Smil,Vaclav
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Smil_Vaclav.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Smil_Vaclav.txt exists already & overwrite is not set. ending here...
# Elkins,James
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Elkins_James.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Elkins_James.txt exists already & overwrite is not set. ending here...
# Lawson,Bryan
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Lawson_Bryan.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Lawson_Bryan.txt exists already & overwrite is not set. ending here...
# Daly,Herman
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Daly_Herman.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Daly_Herman.txt exists already & overwrite is not set. ending here...
# Marshall,Peter
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Marshall_Peter.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Marshall_Peter.txt exists already & overwrite is not set. ending here...
# Krech Iii,Shepard
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Krech Iii_Shepard.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Krech Iii_Shepard.txt exists already & overwrite is not set. ending here...
# Shaw,Malcolm
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Shaw_Malcolm.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Shaw_Malcolm.txt exists already & overwrite is not set. ending here...
# Demeny,Mcnicoll
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Demeny_Mcnicoll.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Demeny_Mcnicoll.txt exists already & overwrite is not set. ending here...
# Johnson,Cb
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Johnson_Cb.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Johnson_Cb.txt exists already & overwrite is not set. ending here...
# Castells,Haraway
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Castells_Haraway.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Castells_Haraway.txt exists already & overwrite is not set. ending here...
# Berkman,Alexander
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Berkman_Alexander.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Berkman_Alexander.txt exists already & overwrite is not set. ending here...
# Diamond,Jared
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Diamond_Jared.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Diamond_Jared.txt exists already & overwrite is not set. ending here...
# Jensen,Derrick
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Jensen_Derrick.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Jensen_Derrick.txt exists already & overwrite is not set. ending here...
# Drake,William
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Drake_William.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Drake_William.txt exists already & overwrite is not set. ending here...
# Lewis,Troy
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Lewis_Troy.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Lewis_Troy.txt exists already & overwrite is not set. ending here...
# Kropotkin,Peter
# /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/
# Creating: /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Kropotkin_Peter.txt
# File /Users/raminsoleymani/git/ECO/data/NAIL_DATAFIELD_txt/parsed_v3/merged/Kropotkin_Peter.txt exists already & overwrite is not set. ending here...
# ALL DONE

# %%
# %run -n ../../v4/pytorch_RVAE/train_word_embeddings.py
# %run -n ../../v4/pytorch_RVAE/train.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/git/ECO/src/v4/pytorch_RVAE/train_word_embeddings.py in <module>()
#       2
#       3 import numpy as np
# ----> 4 import torch as t
#       5 from torch.autograd import Variable
#       6 from torch.optim import SGD
#
# ImportError: No module named 'torch'

# %%
# from pytorch_RVAE import train_word_embeddings 
import shutil
import os

def author_folder_name(author_name):
    return author_name.replace(",","_")

def prepare_rvae_train(author_name,log_file,rvae_data_folder):
    merged_file = merge_docs(author_name,log_file)
    split_for_train_test(merged_file,rvae_data_folder,overwrite=True)

def run_rvae():
    train_word_embeddings.run()
    train.run()
    pass

def move_rvae_model_files(rvae_data_folder, model_folder):
    model_files = os.listdir(rvae_data_folder)
    for file in model_files:
        shutil.move(rvae_data_folder + file,model_folder + file)
    
log_file = 'log-final.json'
rvae_data_folder = get_project_folder() + 'src/v4/pytorch_RVAE/data/'
author_model_folder = get_data_folder() + author_folder_name('Chomsky,Noam') + '/'
        
prepare_rvae_train(rvae_data_folder,author_model_folder)
run_rvae()
move_rvae_model_files()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-3ff8bef5acb4> in <module>()
# ----> 1 from pytorch_RVAE import train_word_embeddings
#       2
#       3 def prepare_rvae_train(author_name,log_file,rvae_data_folder):
#       4     merged_file = merge_docs(author_name,log_file)
#       5     split_for_train_test(merged_file,rvae_data_folder,overwrite=True)
#
# ImportError: No module named 'pytorch_RVAE'
