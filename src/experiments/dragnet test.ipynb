# %%
# https://github.com/seomoz/dragnet
#!pip install lxml
# !pip install libxml
# !CPATH=/Applications/Xcode.app/Contents/Developer/Platforms/MacOSX.platform/Developer/SDKs/MacOSX10.9.sdk/usr/include/libxml2 CFLAGS=-Qunused-arguments CPPFLAGS=-Qunused-arguments pip install lxml
# !pip install --upgrade cython
# !pip install dragnet
# Out:
# Collecting libxml
#   Could not find a version that satisfies the requirement libxml (from versions: )
# No matching distribution found for libxml
# Requirement already satisfied: lxml in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages
# Requirement already up-to-date: cython in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages
# Collecting dragnet
#   Using cached dragnet-1.1.0.tar.gz
# Requirement already satisfied: Cython>=0.21.1 in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: lxml in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: scikit-learn<0.19.0,>=0.15.2 in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: numpy in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: scipy in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: mozsci in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: simplejson in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from mozsci->dragnet)
# Requirement already satisfied: six in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from mozsci->dragnet)
# Requirement already satisfied: nose in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from mozsci->dragnet)
# Requirement already satisfied: coverage in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from mozsci->dragnet)
# Building wheels for collected packages: dragnet
# error
#   Complete output from command /Users/raminsoleymani/git/ECO/src/venv/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-build-ccSnZx/dragnet/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/tmpXGo0pupip-wheel- --python-tag cp27:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.6-intel-2.7
#   creating build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/__init__.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/compat.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/content_extraction_model.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/data_processing.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/features.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/kmeans.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/kohlschuetter.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/model_training.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/models.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/util.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/weninger.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models
#   creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#   copying dragnet/pickled_models/sklearn_0.15.2_0.17.1/kohlschuetter_weninger_readability_content_comments_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#   copying dragnet/pickled_models/sklearn_0.15.2_0.17.1/kohlschuetter_weninger_readability_content_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#   creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#   copying dragnet/pickled_models/sklearn_0.18.0/kohlschuetter_weninger_readability_content_comments_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#   copying dragnet/pickled_models/sklearn_0.18.0/kohlschuetter_weninger_readability_content_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#   running build_ext
#   skipping 'dragnet/_weninger.cpp' Cython extension (up-to-date)
#   building 'dragnet._weninger' extension
#   creating build/temp.macosx-10.6-intel-2.7
#   creating build/temp.macosx-10.6-intel-2.7/dragnet
#   /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/_weninger.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/_weninger.o
#   In file included from dragnet/_weninger.cpp:251:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#   /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#   #warning "Using deprecated NumPy API, disable it by " \
#    ^
#   dragnet/_weninger.cpp:6228:28: warning: unused function '__Pyx_PyObject_AsString' [-Wunused-function]
#   static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#                              ^
#   dragnet/_weninger.cpp:6225:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
#   static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                  ^
#   dragnet/_weninger.cpp:339:29: warning: unused function '__Pyx_Py_UNICODE_strlen' [-Wunused-function]
#   static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u)
#                               ^
#   dragnet/_weninger.cpp:6340:33: warning: unused function '__Pyx_PyIndex_AsSsize_t' [-Wunused-function]
#   static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#                                   ^
#   dragnet/_weninger.cpp:6402:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
#   static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                   ^
#   dragnet/_weninger.cpp:5414:32: warning: unused function '__Pyx_PyInt_From_long' [-Wunused-function]
#   static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value) {
#                                  ^
#   dragnet/_weninger.cpp:5651:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#       static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                  ^
#   dragnet/_weninger.cpp:5771:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#       static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                   ^
#   dragnet/_weninger.cpp:5915:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
#   static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                             ^
#   dragnet/_weninger.cpp:2646:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                  ^
#   dragnet/_weninger.cpp:2696:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                  ^
#   dragnet/_weninger.cpp:2746:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                  ^
#   dragnet/_weninger.cpp:2796:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d) {
#                                  ^
#   dragnet/_weninger.cpp:2846:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d, PyObject *__pyx_v_e) {
#                                  ^
#   dragnet/_weninger.cpp:3654:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
#   static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                             ^
#   dragnet/_weninger.cpp:3750:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                  ^
#   17 warnings generated.
#   In file included from dragnet/_weninger.cpp:251:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#   /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#   #warning "Using deprecated NumPy API, disable it by " \
#    ^
#   dragnet/_weninger.cpp:6228:28: warning: unused function '__Pyx_PyObject_AsString' [-Wunused-function]
#   static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#                              ^
#   dragnet/_weninger.cpp:6225:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
#   static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                  ^
#   dragnet/_weninger.cpp:339:29: warning: unused function '__Pyx_Py_UNICODE_strlen' [-Wunused-function]
#   static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u)
#                               ^
#   dragnet/_weninger.cpp:6340:33: warning: unused function '__Pyx_PyIndex_AsSsize_t' [-Wunused-function]
#   static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#                                   ^
#   dragnet/_weninger.cpp:6402:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
#   static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                   ^
#   dragnet/_weninger.cpp:5414:32: warning: unused function '__Pyx_PyInt_From_long' [-Wunused-function]
#   static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value) {
#                                  ^
#   dragnet/_weninger.cpp:5651:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#       static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                  ^
#   dragnet/_weninger.cpp:5771:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#       static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                   ^
#   dragnet/_weninger.cpp:5915:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
#   static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                             ^
#   dragnet/_weninger.cpp:2646:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                  ^
#   dragnet/_weninger.cpp:2696:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                  ^
#   dragnet/_weninger.cpp:2746:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                  ^
#   dragnet/_weninger.cpp:2796:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d) {
#                                  ^
#   dragnet/_weninger.cpp:2846:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d, PyObject *__pyx_v_e) {
#                                  ^
#   dragnet/_weninger.cpp:3654:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
#   static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                             ^
#   dragnet/_weninger.cpp:3750:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                  ^
#   17 warnings generated.
#   /usr/bin/clang++ -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-2.7/dragnet/_weninger.o -o build/lib.macosx-10.6-intel-2.7/dragnet/_weninger.so
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   cythoning dragnet/lcs.pyx to dragnet/lcs.cpp
#   building 'dragnet.lcs' extension
#   /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/lcs.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/lcs.o
#   In file included from dragnet/lcs.cpp:449:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#   /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#   #warning "Using deprecated NumPy API, disable it by " \
#    ^
#   1 warning generated.
#   In file included from dragnet/lcs.cpp:449:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#   /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#   #warning "Using deprecated NumPy API, disable it by " \
#    ^
#   1 warning generated.
#   /usr/bin/clang++ -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-2.7/dragnet/lcs.o -o build/lib.macosx-10.6-intel-2.7/dragnet/lcs.so
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   cythoning dragnet/blocks.pyx to dragnet/blocks.cpp
#   warning: dragnet/blocks.pyx:172:29: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
#   warning: dragnet/blocks.pyx:172:36: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
#   warning: dragnet/blocks.pyx:586:33: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
#   warning: dragnet/blocks.pyx:586:40: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
#   building 'dragnet.blocks' extension
#   /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/lxml/includes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/lxml -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/blocks.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/blocks.o
#   dragnet/blocks.cpp:459:10: fatal error: 'libxml/xmlversion.h' file not found
#   #include "libxml/xmlversion.h"
#            ^
#   1 error generated.
#   error: command '/usr/bin/clang' failed with exit status 1
#
#   ----------------------------------------
#   Failed building wheel for dragnet
#   Running setup.py clean for dragnet
# Failed to build dragnet
# Installing collected packages: dragnet
# error
#     Complete output from command /Users/raminsoleymani/git/ECO/src/venv/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-build-ccSnZx/dragnet/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-IjhkUN-record/install-record.txt --single-version-externally-managed --compile --install-headers /Users/raminsoleymani/git/ECO/src/venv/bin/../include/site/python2.7/dragnet:
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.6-intel-2.7
#     creating build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/__init__.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/compat.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/content_extraction_model.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/data_processing.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/features.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/kmeans.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/kohlschuetter.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/model_training.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/models.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/util.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/weninger.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models
#     creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#     copying dragnet/pickled_models/sklearn_0.15.2_0.17.1/kohlschuetter_weninger_readability_content_comments_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#     copying dragnet/pickled_models/sklearn_0.15.2_0.17.1/kohlschuetter_weninger_readability_content_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#     creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#     copying dragnet/pickled_models/sklearn_0.18.0/kohlschuetter_weninger_readability_content_comments_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#     copying dragnet/pickled_models/sklearn_0.18.0/kohlschuetter_weninger_readability_content_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#     running build_ext
#     skipping 'dragnet/_weninger.cpp' Cython extension (up-to-date)
#     building 'dragnet._weninger' extension
#     creating build/temp.macosx-10.6-intel-2.7
#     creating build/temp.macosx-10.6-intel-2.7/dragnet
#     /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/_weninger.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/_weninger.o
#     In file included from dragnet/_weninger.cpp:251:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#     /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#     #warning "Using deprecated NumPy API, disable it by " \
#      ^
#     dragnet/_weninger.cpp:6228:28: warning: unused function '__Pyx_PyObject_AsString' [-Wunused-function]
#     static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#                                ^
#     dragnet/_weninger.cpp:6225:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
#     static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                    ^
#     dragnet/_weninger.cpp:339:29: warning: unused function '__Pyx_Py_UNICODE_strlen' [-Wunused-function]
#     static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u)
#                                 ^
#     dragnet/_weninger.cpp:6340:33: warning: unused function '__Pyx_PyIndex_AsSsize_t' [-Wunused-function]
#     static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#                                     ^
#     dragnet/_weninger.cpp:6402:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
#     static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                     ^
#     dragnet/_weninger.cpp:5414:32: warning: unused function '__Pyx_PyInt_From_long' [-Wunused-function]
#     static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value) {
#                                    ^
#     dragnet/_weninger.cpp:5651:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                    ^
#     dragnet/_weninger.cpp:5771:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                     ^
#     dragnet/_weninger.cpp:5915:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
#     static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                               ^
#     dragnet/_weninger.cpp:2646:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                    ^
#     dragnet/_weninger.cpp:2696:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                    ^
#     dragnet/_weninger.cpp:2746:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                    ^
#     dragnet/_weninger.cpp:2796:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d) {
#                                    ^
#     dragnet/_weninger.cpp:2846:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d, PyObject *__pyx_v_e) {
#                                    ^
#     dragnet/_weninger.cpp:3654:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
#     static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                               ^
#     dragnet/_weninger.cpp:3750:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                    ^
#     17 warnings generated.
#     In file included from dragnet/_weninger.cpp:251:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#     /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#     #warning "Using deprecated NumPy API, disable it by " \
#      ^
#     dragnet/_weninger.cpp:6228:28: warning: unused function '__Pyx_PyObject_AsString' [-Wunused-function]
#     static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#                                ^
#     dragnet/_weninger.cpp:6225:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
#     static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                    ^
#     dragnet/_weninger.cpp:339:29: warning: unused function '__Pyx_Py_UNICODE_strlen' [-Wunused-function]
#     static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u)
#                                 ^
#     dragnet/_weninger.cpp:6340:33: warning: unused function '__Pyx_PyIndex_AsSsize_t' [-Wunused-function]
#     static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#                                     ^
#     dragnet/_weninger.cpp:6402:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
#     static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                     ^
#     dragnet/_weninger.cpp:5414:32: warning: unused function '__Pyx_PyInt_From_long' [-Wunused-function]
#     static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value) {
#                                    ^
#     dragnet/_weninger.cpp:5651:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                    ^
#     dragnet/_weninger.cpp:5771:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                     ^
#     dragnet/_weninger.cpp:5915:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
#     static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                               ^
#     dragnet/_weninger.cpp:2646:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                    ^
#     dragnet/_weninger.cpp:2696:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                    ^
#     dragnet/_weninger.cpp:2746:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                    ^
#     dragnet/_weninger.cpp:2796:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d) {
#                                    ^
#     dragnet/_weninger.cpp:2846:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d, PyObject *__pyx_v_e) {
#                                    ^
#     dragnet/_weninger.cpp:3654:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
#     static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                               ^
#     dragnet/_weninger.cpp:3750:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                    ^
#     17 warnings generated.
#     /usr/bin/clang++ -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-2.7/dragnet/_weninger.o -o build/lib.macosx-10.6-intel-2.7/dragnet/_weninger.so
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     skipping 'dragnet/lcs.cpp' Cython extension (up-to-date)
#     building 'dragnet.lcs' extension
#     /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/lcs.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/lcs.o
#     In file included from dragnet/lcs.cpp:449:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#     /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#     #warning "Using deprecated NumPy API, disable it by " \
#      ^
#     1 warning generated.
#     In file included from dragnet/lcs.cpp:449:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#     /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#     #warning "Using deprecated NumPy API, disable it by " \
#      ^
#     1 warning generated.
#     /usr/bin/clang++ -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-2.7/dragnet/lcs.o -o build/lib.macosx-10.6-intel-2.7/dragnet/lcs.so
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     skipping 'dragnet/blocks.cpp' Cython extension (up-to-date)
#     building 'dragnet.blocks' extension
#     /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/lxml/includes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/lxml -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/blocks.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/blocks.o
#     dragnet/blocks.cpp:459:10: fatal error: 'libxml/xmlversion.h' file not found
#     #include "libxml/xmlversion.h"
#              ^
#     1 error generated.
#     error: command '/usr/bin/clang' failed with exit status 1
#
#     ----------------------------------------
# Command "/Users/raminsoleymani/git/ECO/src/venv/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-build-ccSnZx/dragnet/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-IjhkUN-record/install-record.txt --single-version-externally-managed --compile --install-headers /Users/raminsoleymani/git/ECO/src/venv/bin/../include/site/python2.7/dragnet" failed with error code 1 in /private/var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-build-ccSnZx/dragnet/

# %%
import requests
from dragnet import content_extractor, content_comments_extractor

# fetch HTML
url = 'https://moz.com/devblog/dragnet-content-extraction-from-diverse-feature-sets/'
r = requests.get(url)

# get main article without comments
content = content_extractor.analyze(r.content)

# get article and comments
content_comments = content_comments_extractor.analyze(r.content)

# %%
# !brew install --force libxml2
# !brew link libxml2 
# !echo 'export PATH="/usr/local/opt/libxml2/bin:$PATH"' >> ~/.bash_profile
#!brew link --force libxml2
#!brew unlink libxml2 && brew link libxml
# !brew link --force libxml2

# !pip install dragnet
# Out:
# Collecting dragnet
#   Using cached dragnet-1.1.0.tar.gz
# Requirement already satisfied: Cython>=0.21.1 in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: lxml in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: scikit-learn<0.19.0,>=0.15.2 in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: numpy in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: scipy in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: mozsci in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from dragnet)
# Requirement already satisfied: simplejson in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from mozsci->dragnet)
# Requirement already satisfied: six in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from mozsci->dragnet)
# Requirement already satisfied: nose in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from mozsci->dragnet)
# Requirement already satisfied: coverage in /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages (from mozsci->dragnet)
# Building wheels for collected packages: dragnet
# error
#   Complete output from command /Users/raminsoleymani/git/ECO/src/venv/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-build-Pzy4HZ/dragnet/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/tmp1IbALSpip-wheel- --python-tag cp27:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.6-intel-2.7
#   creating build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/__init__.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/compat.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/content_extraction_model.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/data_processing.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/features.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/kmeans.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/kohlschuetter.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/model_training.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/models.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/util.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   copying dragnet/weninger.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#   creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models
#   creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#   copying dragnet/pickled_models/sklearn_0.15.2_0.17.1/kohlschuetter_weninger_readability_content_comments_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#   copying dragnet/pickled_models/sklearn_0.15.2_0.17.1/kohlschuetter_weninger_readability_content_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#   creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#   copying dragnet/pickled_models/sklearn_0.18.0/kohlschuetter_weninger_readability_content_comments_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#   copying dragnet/pickled_models/sklearn_0.18.0/kohlschuetter_weninger_readability_content_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#   running build_ext
#   skipping 'dragnet/_weninger.cpp' Cython extension (up-to-date)
#   building 'dragnet._weninger' extension
#   creating build/temp.macosx-10.6-intel-2.7
#   creating build/temp.macosx-10.6-intel-2.7/dragnet
#   /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/_weninger.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/_weninger.o
#   In file included from dragnet/_weninger.cpp:251:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#   /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#   #warning "Using deprecated NumPy API, disable it by " \
#    ^
#   dragnet/_weninger.cpp:6228:28: warning: unused function '__Pyx_PyObject_AsString' [-Wunused-function]
#   static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#                              ^
#   dragnet/_weninger.cpp:6225:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
#   static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                  ^
#   dragnet/_weninger.cpp:339:29: warning: unused function '__Pyx_Py_UNICODE_strlen' [-Wunused-function]
#   static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u)
#                               ^
#   dragnet/_weninger.cpp:6340:33: warning: unused function '__Pyx_PyIndex_AsSsize_t' [-Wunused-function]
#   static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#                                   ^
#   dragnet/_weninger.cpp:6402:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
#   static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                   ^
#   dragnet/_weninger.cpp:5414:32: warning: unused function '__Pyx_PyInt_From_long' [-Wunused-function]
#   static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value) {
#                                  ^
#   dragnet/_weninger.cpp:5651:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#       static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                  ^
#   dragnet/_weninger.cpp:5771:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#       static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                   ^
#   dragnet/_weninger.cpp:5915:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
#   static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                             ^
#   dragnet/_weninger.cpp:2646:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                  ^
#   dragnet/_weninger.cpp:2696:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                  ^
#   dragnet/_weninger.cpp:2746:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                  ^
#   dragnet/_weninger.cpp:2796:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d) {
#                                  ^
#   dragnet/_weninger.cpp:2846:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d, PyObject *__pyx_v_e) {
#                                  ^
#   dragnet/_weninger.cpp:3654:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
#   static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                             ^
#   dragnet/_weninger.cpp:3750:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                  ^
#   17 warnings generated.
#   In file included from dragnet/_weninger.cpp:251:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#   /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#   #warning "Using deprecated NumPy API, disable it by " \
#    ^
#   dragnet/_weninger.cpp:6228:28: warning: unused function '__Pyx_PyObject_AsString' [-Wunused-function]
#   static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#                              ^
#   dragnet/_weninger.cpp:6225:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
#   static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                  ^
#   dragnet/_weninger.cpp:339:29: warning: unused function '__Pyx_Py_UNICODE_strlen' [-Wunused-function]
#   static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u)
#                               ^
#   dragnet/_weninger.cpp:6340:33: warning: unused function '__Pyx_PyIndex_AsSsize_t' [-Wunused-function]
#   static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#                                   ^
#   dragnet/_weninger.cpp:6402:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
#   static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                   ^
#   dragnet/_weninger.cpp:5414:32: warning: unused function '__Pyx_PyInt_From_long' [-Wunused-function]
#   static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value) {
#                                  ^
#   dragnet/_weninger.cpp:5651:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#       static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                  ^
#   dragnet/_weninger.cpp:5771:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#       static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                   ^
#   dragnet/_weninger.cpp:5915:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
#   static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                             ^
#   dragnet/_weninger.cpp:2646:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                  ^
#   dragnet/_weninger.cpp:2696:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                  ^
#   dragnet/_weninger.cpp:2746:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                  ^
#   dragnet/_weninger.cpp:2796:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d) {
#                                  ^
#   dragnet/_weninger.cpp:2846:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d, PyObject *__pyx_v_e) {
#                                  ^
#   dragnet/_weninger.cpp:3654:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
#   static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                             ^
#   dragnet/_weninger.cpp:3750:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
#   static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                  ^
#   17 warnings generated.
#   /usr/bin/clang++ -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-2.7/dragnet/_weninger.o -o build/lib.macosx-10.6-intel-2.7/dragnet/_weninger.so
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   cythoning dragnet/lcs.pyx to dragnet/lcs.cpp
#   building 'dragnet.lcs' extension
#   /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/lcs.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/lcs.o
#   In file included from dragnet/lcs.cpp:449:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#   /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#   #warning "Using deprecated NumPy API, disable it by " \
#    ^
#   1 warning generated.
#   In file included from dragnet/lcs.cpp:449:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#   /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#   #warning "Using deprecated NumPy API, disable it by " \
#    ^
#   1 warning generated.
#   /usr/bin/clang++ -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-2.7/dragnet/lcs.o -o build/lib.macosx-10.6-intel-2.7/dragnet/lcs.so
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   cythoning dragnet/blocks.pyx to dragnet/blocks.cpp
#   warning: dragnet/blocks.pyx:172:29: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
#   warning: dragnet/blocks.pyx:172:36: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
#   warning: dragnet/blocks.pyx:586:33: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
#   warning: dragnet/blocks.pyx:586:40: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
#   building 'dragnet.blocks' extension
#   /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/lxml/includes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/lxml -I/usr/local/include/libxml2 -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/blocks.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/blocks.o
#   dragnet/blocks.cpp:2063:13: warning: unused function '__pyx_f_7dragnet_6blocks_empty_callback' [-Wunused-function]
#   static void __pyx_f_7dragnet_6blocks_empty_callback(CYTHON_UNUSED struct __pyx_obj_7dragnet_6blocks_PartialBlock *__pyx_v_pb, CYTHON_UNUSED std::string __pyx_v_x) {
#               ^
#   1 warning generated.
#   dragnet/blocks.cpp:2063:13: warning: unused function '__pyx_f_7dragnet_6blocks_empty_callback' [-Wunused-function]
#   static void __pyx_f_7dragnet_6blocks_empty_callback(CYTHON_UNUSED struct __pyx_obj_7dragnet_6blocks_PartialBlock *__pyx_v_pb, CYTHON_UNUSED std::string __pyx_v_x) {
#               ^
#   1 warning generated.
#   /usr/bin/clang++ -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-2.7/dragnet/blocks.o -lxml2 -o build/lib.macosx-10.6-intel-2.7/dragnet/blocks.so
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   skipping 'dragnet/readability.cpp' Cython extension (up-to-date)
#   building 'dragnet.readability' extension
#   /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/readability.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/readability.o -std=c++0x
#   In file included from dragnet/readability.cpp:449:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#   In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#   /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#   #warning "Using deprecated NumPy API, disable it by " \
#    ^
#   In file included from dragnet/readability.cpp:459:
#   dragnet/_readability.cc:4:10: fatal error: 'unordered_map' file not found
#   #include <unordered_map>
#            ^
#   1 warning and 1 error generated.
#   error: command '/usr/bin/clang' failed with exit status 1
#
#   ----------------------------------------
#   Failed building wheel for dragnet
#   Running setup.py clean for dragnet
# Failed to build dragnet
# Installing collected packages: dragnet
# error
#     Complete output from command /Users/raminsoleymani/git/ECO/src/venv/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-build-Pzy4HZ/dragnet/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-YnJqJE-record/install-record.txt --single-version-externally-managed --compile --install-headers /Users/raminsoleymani/git/ECO/src/venv/bin/../include/site/python2.7/dragnet:
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.6-intel-2.7
#     creating build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/__init__.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/compat.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/content_extraction_model.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/data_processing.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/features.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/kmeans.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/kohlschuetter.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/model_training.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/models.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/util.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     copying dragnet/weninger.py -> build/lib.macosx-10.6-intel-2.7/dragnet
#     creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models
#     creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#     copying dragnet/pickled_models/sklearn_0.15.2_0.17.1/kohlschuetter_weninger_readability_content_comments_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#     copying dragnet/pickled_models/sklearn_0.15.2_0.17.1/kohlschuetter_weninger_readability_content_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.15.2_0.17.1
#     creating build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#     copying dragnet/pickled_models/sklearn_0.18.0/kohlschuetter_weninger_readability_content_comments_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#     copying dragnet/pickled_models/sklearn_0.18.0/kohlschuetter_weninger_readability_content_model.pickle.gz -> build/lib.macosx-10.6-intel-2.7/dragnet/pickled_models/sklearn_0.18.0
#     running build_ext
#     skipping 'dragnet/_weninger.cpp' Cython extension (up-to-date)
#     building 'dragnet._weninger' extension
#     creating build/temp.macosx-10.6-intel-2.7
#     creating build/temp.macosx-10.6-intel-2.7/dragnet
#     /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/_weninger.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/_weninger.o
#     In file included from dragnet/_weninger.cpp:251:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#     /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#     #warning "Using deprecated NumPy API, disable it by " \
#      ^
#     dragnet/_weninger.cpp:6228:28: warning: unused function '__Pyx_PyObject_AsString' [-Wunused-function]
#     static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#                                ^
#     dragnet/_weninger.cpp:6225:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
#     static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                    ^
#     dragnet/_weninger.cpp:339:29: warning: unused function '__Pyx_Py_UNICODE_strlen' [-Wunused-function]
#     static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u)
#                                 ^
#     dragnet/_weninger.cpp:6340:33: warning: unused function '__Pyx_PyIndex_AsSsize_t' [-Wunused-function]
#     static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#                                     ^
#     dragnet/_weninger.cpp:6402:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
#     static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                     ^
#     dragnet/_weninger.cpp:5414:32: warning: unused function '__Pyx_PyInt_From_long' [-Wunused-function]
#     static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value) {
#                                    ^
#     dragnet/_weninger.cpp:5651:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                    ^
#     dragnet/_weninger.cpp:5771:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                     ^
#     dragnet/_weninger.cpp:5915:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
#     static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                               ^
#     dragnet/_weninger.cpp:2646:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                    ^
#     dragnet/_weninger.cpp:2696:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                    ^
#     dragnet/_weninger.cpp:2746:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                    ^
#     dragnet/_weninger.cpp:2796:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d) {
#                                    ^
#     dragnet/_weninger.cpp:2846:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d, PyObject *__pyx_v_e) {
#                                    ^
#     dragnet/_weninger.cpp:3654:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
#     static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                               ^
#     dragnet/_weninger.cpp:3750:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                    ^
#     17 warnings generated.
#     In file included from dragnet/_weninger.cpp:251:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#     /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#     #warning "Using deprecated NumPy API, disable it by " \
#      ^
#     dragnet/_weninger.cpp:6228:28: warning: unused function '__Pyx_PyObject_AsString' [-Wunused-function]
#     static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#                                ^
#     dragnet/_weninger.cpp:6225:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
#     static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                    ^
#     dragnet/_weninger.cpp:339:29: warning: unused function '__Pyx_Py_UNICODE_strlen' [-Wunused-function]
#     static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u)
#                                 ^
#     dragnet/_weninger.cpp:6340:33: warning: unused function '__Pyx_PyIndex_AsSsize_t' [-Wunused-function]
#     static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#                                     ^
#     dragnet/_weninger.cpp:6402:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
#     static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                     ^
#     dragnet/_weninger.cpp:5414:32: warning: unused function '__Pyx_PyInt_From_long' [-Wunused-function]
#     static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value) {
#                                    ^
#     dragnet/_weninger.cpp:5651:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                    ^
#     dragnet/_weninger.cpp:5771:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                     ^
#     dragnet/_weninger.cpp:5915:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
#     static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                               ^
#     dragnet/_weninger.cpp:2646:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                    ^
#     dragnet/_weninger.cpp:2696:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                    ^
#     dragnet/_weninger.cpp:2746:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                    ^
#     dragnet/_weninger.cpp:2796:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d) {
#                                    ^
#     dragnet/_weninger.cpp:2846:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *__pyx_v_d, PyObject *__pyx_v_e) {
#                                    ^
#     dragnet/_weninger.cpp:3654:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
#     static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                               ^
#     dragnet/_weninger.cpp:3750:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
#     static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                    ^
#     17 warnings generated.
#     /usr/bin/clang++ -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-2.7/dragnet/_weninger.o -o build/lib.macosx-10.6-intel-2.7/dragnet/_weninger.so
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     skipping 'dragnet/lcs.cpp' Cython extension (up-to-date)
#     building 'dragnet.lcs' extension
#     /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/lcs.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/lcs.o
#     In file included from dragnet/lcs.cpp:449:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#     /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#     #warning "Using deprecated NumPy API, disable it by " \
#      ^
#     1 warning generated.
#     In file included from dragnet/lcs.cpp:449:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#     /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#     #warning "Using deprecated NumPy API, disable it by " \
#      ^
#     1 warning generated.
#     /usr/bin/clang++ -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-2.7/dragnet/lcs.o -o build/lib.macosx-10.6-intel-2.7/dragnet/lcs.so
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     skipping 'dragnet/blocks.cpp' Cython extension (up-to-date)
#     building 'dragnet.blocks' extension
#     /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/lxml/includes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/lxml -I/usr/local/include/libxml2 -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/blocks.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/blocks.o
#     dragnet/blocks.cpp:2063:13: warning: unused function '__pyx_f_7dragnet_6blocks_empty_callback' [-Wunused-function]
#     static void __pyx_f_7dragnet_6blocks_empty_callback(CYTHON_UNUSED struct __pyx_obj_7dragnet_6blocks_PartialBlock *__pyx_v_pb, CYTHON_UNUSED std::string __pyx_v_x) {
#                 ^
#     1 warning generated.
#     dragnet/blocks.cpp:2063:13: warning: unused function '__pyx_f_7dragnet_6blocks_empty_callback' [-Wunused-function]
#     static void __pyx_f_7dragnet_6blocks_empty_callback(CYTHON_UNUSED struct __pyx_obj_7dragnet_6blocks_PartialBlock *__pyx_v_pb, CYTHON_UNUSED std::string __pyx_v_x) {
#                 ^
#     1 warning generated.
#     /usr/bin/clang++ -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-2.7/dragnet/blocks.o -lxml2 -o build/lib.macosx-10.6-intel-2.7/dragnet/blocks.so
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     skipping 'dragnet/readability.cpp' Cython extension (up-to-date)
#     building 'dragnet.readability' extension
#     /usr/bin/clang -fno-strict-aliasing -fno-common -dynamic -arch i386 -arch x86_64 -g -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/2.7/include/python2.7 -c dragnet/readability.cpp -o build/temp.macosx-10.6-intel-2.7/dragnet/readability.o -std=c++0x
#     In file included from dragnet/readability.cpp:449:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
#     In file included from /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
#     /Users/raminsoleymani/git/ECO/src/venv/lib/python2.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: "Using deprecated NumPy API, disable it by "          "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#     #warning "Using deprecated NumPy API, disable it by " \
#      ^
#     In file included from dragnet/readability.cpp:459:
#     dragnet/_readability.cc:4:10: fatal error: 'unordered_map' file not found
#     #include <unordered_map>
#              ^
#     1 warning and 1 error generated.
#     error: command '/usr/bin/clang' failed with exit status 1
#
#     ----------------------------------------
# Command "/Users/raminsoleymani/git/ECO/src/venv/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-build-Pzy4HZ/dragnet/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-YnJqJE-record/install-record.txt --single-version-externally-managed --compile --install-headers /Users/raminsoleymani/git/ECO/src/venv/bin/../include/site/python2.7/dragnet" failed with error code 1 in /private/var/folders/vg/h447t9h54dq9t83jynkzlj5c000197/T/pip-build-Pzy4HZ/dragnet/
