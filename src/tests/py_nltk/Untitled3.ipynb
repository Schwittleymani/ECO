# %% [markdown]
# Twitter

# %%
import os, sys; 
#sys.path.insert(0, ".", "..", ".."))

from pattern.web import Twitter, hashtags
from pattern.db  import Datasheet, pprint, pd

# This example retrieves tweets containing given keywords from Twitter.

try: 
    # We'll store tweets in a Datasheet.
    # A Datasheet is a table of rows and columns that can be exported as a CSV-file.
    # In the first column, we'll store a unique id for each tweet.
    # We only want to add the latest tweets, i.e., those we haven't seen yet.
    # With an index on the first column we can quickly check if an id already exists.
    # The pd() function returns the parent directory of this script + any given path.
    table = Datasheet.load(pd("cool.csv"))
    index = set(table.columns[0])
except:
    table = Datasheet()
    index = set()

engine = Twitter(language="en")

# With Twitter.search(cached=False), a "live" request is sent to Twitter:
# we get the most recent results instead of those in the local cache.
# Keeping a local cache can also be useful (e.g., while testing)
# because a query is instant when it is executed the second time.
prev = None
for i in range(2):
    print i
    for tweet in engine.search("is cooler than", start=prev, count=25, cached=False):
        print
        print tweet.text
        print tweet.author
        print tweet.date
        print hashtags(tweet.text) # Keywords in tweets start with a "#".
        print
        # Only add the tweet to the table if it doesn't already exists.
        if len(table) == 0 or tweet.id not in index:
            table.append([tweet.id, tweet.text])
            index.add(tweet.id)
        # Continue mining older tweets in next iteration.
        prev = tweet.id

# Create a .csv in pattern/examples/01-web/
table.save(pd("cool.csv"))

print "Total results:", len(table)
print

# Print all the rows in the table.
# Since it is stored as a CSV-file it grows comfortably each time the script runs.
# We can also open the table later on: in other scripts, for further analysis, ...

pprint(table, truncate=100)

# Note: you can also search tweets by author:
# Twitter().search("from:tom_de_smedt")
# Out:
# 0
#
# RT @MMP_UTK: Oh Me,Oh My! Your Contest #3, Kenneth D. Richmond, is cooler than a Coogi Sweater &amp; exudes style and charm in any type of weat…
# OohsoGenie
# Wed Oct 26 23:20:13 +0000 2016
# [u'#3']
#
#
# RT @LaytonEWilliams: Post-work hootenanny at @Sojourners. My work is cooler than your work. #SojoLife #mypeople https://t.co/ZIzDQPoA9W
# Sojourners
# Wed Oct 26 23:17:49 +0000 2016
# [u'#SojoLife', u'#mypeople']
#
#
# The NBA is 5,000 times cooler than the NFL. #PACERNATION
# sbizila
# Wed Oct 26 23:13:50 +0000 2016
# [u'#PACERNATION']
#
#
# @tornado__ii This bird is cooler than me
# Tiramiswhat
# Wed Oct 26 23:13:17 +0000 2016
# []
#
#
# My dog is definitely cooler than me https://t.co/GBHjEtBjvy
# ldy3r97
# Wed Oct 26 23:07:54 +0000 2016
# []
#
#
# RT @ChiBuildings: How is it possible that the new sections of the riverwalk are cooler than last year's new sections? https://t.co/FfCNPGaD…
# ski7days
# Wed Oct 26 23:03:51 +0000 2016
# []
#
#
# How is it possible that the new sections of the riverwalk are cooler than last year's new sections? https://t.co/FfCNPGaDlB
# ChiBuildings
# Wed Oct 26 23:01:33 +0000 2016
# []
#
#
# This is my Uncle Jim and he's definitely cooler than you tbh https://t.co/FTW0PZCheG
# lizzielovesbleu
# Wed Oct 26 23:00:10 +0000 2016
# []
#
#
# RT @paige____wells: Our squad is cooler than yours https://t.co/KISSYwdOdE
# karleythomas0
# Wed Oct 26 22:58:52 +0000 2016
# []
#
#
# Is it true Femi is cooler than u? — sasuke &gt; naruto https://t.co/6fosiyHPAZ
# olaoluslawn
# Wed Oct 26 22:57:57 +0000 2016
# []
#
#
# @GeorgeKalec first of all I deserved to be the peanut butter cause I'm cooler than you. Second food is great soooo.
# cheyenne_122
# Wed Oct 26 22:57:45 +0000 2016
# []
#
#
# My favorite team is cooler than your favorite team. The end. 🍀 https://t.co/iRxoAzaMkq
# TrillTessa
# Wed Oct 26 22:56:56 +0000 2016
# []
#
#
# RT @davehillphoto: Wow. When Microsoft is doing cooler things than Apple. Surface Studio looks amazing. https://t.co/SgjOInHQL1
# aliriffai
# Wed Oct 26 22:55:51 +0000 2016
# []
#
#
# My great grandma is 90 and is cooler than literally anyone I've ever met
# caleighelectric
# Wed Oct 26 22:54:58 +0000 2016
# []
#
#
# What's cooler than being cool? @EKWaterBlocks + @GIGABYTEUSA! Enter to win an AIO CPU cooler, hoodies, swag &amp; more: https://t.co/YdiFxzjzzn
# AshTheDryad
# Wed Oct 26 22:54:31 +0000 2016
# []
#
#
# RT @GIGABYTEUSA: What's cooler than being cool? @EKWaterBlocks! Enter to win an AIO CPU cooler, hoodies, swag &amp; more. Entry is free: https:…
# charzardl
# Wed Oct 26 22:49:47 +0000 2016
# []
#
#
# RT @GIGABYTEUSA: What's cooler than being cool? @EKWaterBlocks! Enter to win an AIO CPU cooler, hoodies, swag &amp; more. Entry is free: https:…
# SlayerLok
# Wed Oct 26 22:49:24 +0000 2016
# []
#
#
# .@pixeljamgames' Snowball! looks cool. Get it, because the whole game is winter-themed? https://t.co/bmY1l2MObc by @wondroushippo
# toucharcade
# Wed Oct 26 22:45:31 +0000 2016
# []
#
#
# My hairdresser is cooler than yours #moxie #loveit #shorthairdontcare https://t.co/MfHF7KhlYV
# Kristen_Barbour
# Wed Oct 26 22:42:43 +0000 2016
# [u'#moxie', u'#loveit', u'#shorthairdontcare']
#
#
# RT @MMP_UTK: Oh Me,Oh My! Your Contest #3, Kenneth D. Richmond, is cooler than a Coogi Sweater &amp; exudes style and charm in any type of weat…
# S_A_Y_myname
# Wed Oct 26 22:39:44 +0000 2016
# [u'#3']
#
#
# RT @Its_North_West: North West is only 3 and already way cooler than me https://t.co/6G6aoPgXOn
# CoriaJennell
# Wed Oct 26 22:37:28 +0000 2016
# []
#
#
# RT @climatecouncil: 14 reasons why Canberra is way cooler than you think: https://t.co/0UtfhNkFJL #renewables #climateaction #auspol https:…
# mariet888
# Wed Oct 26 22:35:51 +0000 2016
# [u'#renewables', u'#climateaction', u'#auspol']
#
#
# Post-work hootenanny at @Sojourners. My work is cooler than your work. #SojoLife #mypeople https://t.co/ZIzDQPoA9W
# LaytonEWilliams
# Wed Oct 26 22:32:28 +0000 2016
# [u'#SojoLife', u'#mypeople']
#
#
# My dog is cooler than u https://t.co/S258Wyh0If
# ShannonSturtz
# Wed Oct 26 22:32:27 +0000 2016
# []
#
#
# Reason #194 why my school is cooler than yours. https://t.co/u3xxTmVIG8
# miss__defy
# Wed Oct 26 22:32:04 +0000 2016
# [u'#194']
#
# 1
#
# Wonder if this month's average temperature is significantly cooler than last month's... only one way to tell, run a test... #stats6010 #H_0
# thearkaives
# Wed Oct 26 22:30:08 +0000 2016
# [u'#stats6010', u'#H_0']
#
#
# RT @GIGABYTEUSA: What's cooler than being cool? @EKWaterBlocks! Enter to win an AIO CPU cooler, hoodies, swag &amp; more. Entry is free: https:…
# 235_41
# Wed Oct 26 22:29:40 +0000 2016
# []
#
#
# RT @paige____wells: Our squad is cooler than yours https://t.co/KISSYwdOdE
# Travel_2_London
# Wed Oct 26 22:27:24 +0000 2016
# []
#
#
# @JodiesJumpsuit this is exactly the kind of kid id expect you'd have and he's even cooler than that!!!😃😃😃
# CharlottePigg
# Wed Oct 26 22:26:45 +0000 2016
# []
#
#
# My son is cooler than your son. https://t.co/MjPD95WWOf
# thetinkles2dr
# Wed Oct 26 22:26:35 +0000 2016
# []
#
#
# RT @ppearlman: 1st time in history u can make a case that softie is cooler than apple.
# tribeless
# Wed Oct 26 22:25:11 +0000 2016
# []
#
#
# 1st time in history u can make a case that softie is cooler than apple.
# ppearlman
# Wed Oct 26 22:24:10 +0000 2016
# []
#
#
# RT @MassAppeal: ICYMI, @Black_EL released the new video for "EL EL Cool Che." It's dope. https://t.co/S4lWUrbm1c https://t.co/iOosrOPCiU
# IamLatrellJames
# Wed Oct 26 22:23:04 +0000 2016
# []
#
#
# @Tulki I only know of them because a friend who is much cooler than me put me on to them  when we went to see them for her birthday
# vickster1984
# Wed Oct 26 22:15:43 +0000 2016
# []
#
#
# RT @MeganMaitino: My Dad is cooler than yours https://t.co/vTr724zgC0
# annamaitino
# Wed Oct 26 22:15:31 +0000 2016
# []
#
#
# My Dad is cooler than yours https://t.co/vTr724zgC0
# MeganMaitino
# Wed Oct 26 22:14:58 +0000 2016
# []
#
#
# I wonder if my look alike is cooler than me
# jaehunnybum
# Wed Oct 26 22:14:41 +0000 2016
# []
#
#
# RT @londonphotodir: Whatch and think? Storm Trooper Wood Carving - Nothing is cooler than this [via https://t.co/Iwi5TlhxqG] https://t.co/F…
# insprme
# Wed Oct 26 22:11:38 +0000 2016
# []
#
#
# RT @__JustCallMeSin: My horse is cooler than u xox https://t.co/ZpacWGZ3R8
# RobDevine3
# Wed Oct 26 22:10:34 +0000 2016
# []
#
#
# But why is my mom cooler, hotter, smarter, and more badass than me
# laurendianne18
# Wed Oct 26 22:10:15 +0000 2016
# []
#
#
# Um an astronaut is way cooler than Russell Wilson. #sorrynotsorry https://t.co/ICqnEWK3A6
# karaevenson
# Wed Oct 26 22:06:08 +0000 2016
# [u'#sorrynotsorry']
#
#
# The #Surface from @Microsoft is now officially cooler than @apple https://t.co/OKCravpFYt https://t.co/vXPvf4s8kW
# PaoloMiscia
# Wed Oct 26 22:04:36 +0000 2016
# [u'#Surface']
#
#
# RT @GIGABYTEUSA: What's cooler than being cool? @EKWaterBlocks! Enter to win an AIO CPU cooler, hoodies, swag &amp; more. Entry is free: https:…
# RNZippler
# Wed Oct 26 22:03:34 +0000 2016
# []
#
#
# RT @__OgGleesh_: Cooler is better than Freiza
# Ldrew602
# Wed Oct 26 22:02:07 +0000 2016
# []
#
#
# @guskamp @SabCarpenterHQ is cooler than you sorry not sorry dude
# wydfiym
# Wed Oct 26 22:01:50 +0000 2016
# []
#
#
# @dever_o @Ethan_Booker @WalshFreedom The real Joe Walsh is much cooler than this bogus pretender!
# LargeFatherV
# Wed Oct 26 22:00:53 +0000 2016
# []
#
#
# My manager is cooler than your's
# messnickness
# Wed Oct 26 22:00:51 +0000 2016
# []
#
#
# RT @_laurensteele: guilty pleasure is stalking kids i went to school w to realize i am in fact cooler than them as i always thought
# maleukma
# Wed Oct 26 22:00:19 +0000 2016
# []
#
#
# @villainlily ITS PIZZA TIME! 100 million times cooler than a pirate. Props for not choosing Rafael too! my fav is Leo though.mike 2nd
# OpenMindedGame
# Wed Oct 26 21:59:01 +0000 2016
# []
#
#
# My horse is cooler than u xox https://t.co/ZpacWGZ3R8
# __JustCallMeSin
# Wed Oct 26 21:58:28 +0000 2016
# []
#
# Total results: 50
#
# 791419190175555584  RT @MMP_UTK: Oh Me,Oh My! Your Contest #3, Kenneth D. Richmond, is cooler than a Coogi Sweater &amp;
#                     exudes style and charm in any type of weat….........................................................
# 791418584610242563  RT @LaytonEWilliams: Post-work hootenanny at @Sojourners. My work is cooler than your work..........
#                     #SojoLife #mypeople https://t.co/ZIzDQPoA9W.........................................................
# 791417585715642369  The NBA is 5,000 times cooler than the NFL. #PACERNATION............................................
# 791417447186309120  @tornado__ii This bird is cooler than me............................................................
# 791416092346425344  My dog is definitely cooler than me https://t.co/GBHjEtBjvy.........................................
# 791415071796785152  RT @ChiBuildings: How is it possible that the new sections of the riverwalk are cooler than last....
#                     year's new sections? https://t.co/FfCNPGaD….........................................................
# 791414491133059072  How is it possible that the new sections of the riverwalk are cooler than last year's new sections?.
#                     https://t.co/FfCNPGaDlB.............................................................................
# 791414145124069376  This is my Uncle Jim and he's definitely cooler than you tbh https://t.co/FTW0PZCheG................
# 791413817003630592  RT @paige____wells: Our squad is cooler than yours https://t.co/KISSYwdOdE..........................
# 791413586098782213  Is it true Femi is cooler than u? — sasuke &gt; naruto https://t.co/6fosiyHPAZ......................
# 791413535926607872  @GeorgeKalec first of all I deserved to be the peanut butter cause I'm cooler than you. Second food.
#                     is great soooo......................................................................................
# 791413329336098816  My favorite team is cooler than your favorite team. The end. 🍀 https://t.co/iRxoAzaMkq.............
# 791413060162453504  RT @davehillphoto: Wow. When Microsoft is doing cooler things than Apple. Surface Studio looks......
#                     amazing. https://t.co/SgjOInHQL1....................................................................
# 791412836576657408  My great grandma is 90 and is cooler than literally anyone I've ever met............................
# 791412722168725504  What's cooler than being cool? @EKWaterBlocks + @GIGABYTEUSA! Enter to win an AIO CPU cooler,.......
#                     hoodies, swag &amp; more: https://t.co/YdiFxzjzzn...................................................
# 791411531829260288  RT @GIGABYTEUSA: What's cooler than being cool? @EKWaterBlocks! Enter to win an AIO CPU cooler,.....
#                     hoodies, swag &amp; more. Entry is free: https:…....................................................
# 791411436777902080  RT @GIGABYTEUSA: What's cooler than being cool? @EKWaterBlocks! Enter to win an AIO CPU cooler,.....
#                     hoodies, swag &amp; more. Entry is free: https:…....................................................
# 791410456317468672  .@pixeljamgames' Snowball! looks cool. Get it, because the whole game is winter-themed?.............
#                     https://t.co/bmY1l2MObc by @wondroushippo...........................................................
# 791409754086277120  My hairdresser is cooler than yours #moxie #loveit #shorthairdontcare https://t.co/MfHF7KhlYV.......
# 791409003653894144  RT @MMP_UTK: Oh Me,Oh My! Your Contest #3, Kenneth D. Richmond, is cooler than a Coogi Sweater &amp;
#                     exudes style and charm in any type of weat….........................................................
# 791408431387127808  RT @Its_North_West: North West is only 3 and already way cooler than me https://t.co/6G6aoPgXOn.....
# 791408025957347329  RT @climatecouncil: 14 reasons why Canberra is way cooler than you think: https://t.co/0UtfhNkFJL...
#                     #renewables #climateaction #auspol https:…..........................................................
# 791407173792370692  Post-work hootenanny at @Sojourners. My work is cooler than your work. #SojoLife #mypeople..........
#                     https://t.co/ZIzDQPoA9W.............................................................................
# 791407170113966081  My dog is cooler than u https://t.co/S258Wyh0If.....................................................
# 791407074425143297  Reason #194 why my school is cooler than yours. https://t.co/u3xxTmVIG8.............................
# 791406585243459590  Wonder if this month's average temperature is significantly cooler than last month's... only one way
#                     to tell, run a test... #stats6010 #H_0..............................................................
# 791406467660128256  RT @GIGABYTEUSA: What's cooler than being cool? @EKWaterBlocks! Enter to win an AIO CPU cooler,.....
#                     hoodies, swag &amp; more. Entry is free: https:…....................................................
# 791405897708933120  RT @paige____wells: Our squad is cooler than yours https://t.co/KISSYwdOdE..........................
# 791405732994220032  @JodiesJumpsuit this is exactly the kind of kid id expect you'd have and he's even cooler than......
#                     that!!!😃😃😃.......................................................................................
# 791405694020902912  My son is cooler than your son. https://t.co/MjPD95WWOf.............................................
# 791405339958620160  RT @ppearlman: 1st time in history u can make a case that softie is cooler than apple...............
# 791405082961121281  1st time in history u can make a case that softie is cooler than apple..............................
# 791404806032293888  RT @MassAppeal: ICYMI, @Black_EL released the new video for "EL EL Cool Che." It's dope.............
#                     https://t.co/S4lWUrbm1c https://t.co/iOosrOPCiU.....................................................
# 791402957971554304  @Tulki I only know of them because a friend who is much cooler than me put me on to them  when we...
#                     went to see them for her birthday...................................................................
# 791402906633310209  RT @MeganMaitino: My Dad is cooler than yours https://t.co/vTr724zgC0...............................
# 791402768837771264  My Dad is cooler than yours https://t.co/vTr724zgC0.................................................
# 791402696985174017  I wonder if my look alike is cooler than me.........................................................
# 791401931432398849  RT @londonphotodir: Whatch and think? Storm Trooper Wood Carving - Nothing is cooler than this [via.
#                     https://t.co/Iwi5TlhxqG] https://t.co/F…............................................................
# 791401663122866176  RT @__JustCallMeSin: My horse is cooler than u xox https://t.co/ZpacWGZ3R8..........................
# 791401583691038720  But why is my mom cooler, hotter, smarter, and more badass than me..................................
# 791400545462300672  Um an astronaut is way cooler than Russell Wilson. #sorrynotsorry https://t.co/ICqnEWK3A6...........
# 791400161058623488  The #Surface from @Microsoft is now officially cooler than @apple https://t.co/OKCravpFYt...........
#                     https://t.co/vXPvf4s8kW.............................................................................
# 791399902785875970  RT @GIGABYTEUSA: What's cooler than being cool? @EKWaterBlocks! Enter to win an AIO CPU cooler,.....
#                     hoodies, swag &amp; more. Entry is free: https:…....................................................
# 791399534215569408  RT @__OgGleesh_: Cooler is better than Freiza.......................................................
# 791399463743004673  @guskamp @SabCarpenterHQ is cooler than you sorry not sorry dude....................................
# 791399227092074497  @dever_o @Ethan_Booker @WalshFreedom The real Joe Walsh is much cooler than this bogus pretender!...
# 791399216278966272  My manager is cooler than your's....................................................................
# 791399081465769984  RT @_laurensteele: guilty pleasure is stalking kids i went to school w to realize i am in fact......
#                     cooler than them as i always thought................................................................
# 791398755635490816  @villainlily ITS PIZZA TIME! 100 million times cooler than a pirate. Props for not choosing Rafael..
#                     too! my fav is Leo though.mike 2nd..................................................................
# 791398618632683520  My horse is cooler than u xox https://t.co/ZpacWGZ3R8...............................................

# %% [markdown]
# Google

# %%
import os, sys

from pattern.web import Google, plaintext
from pattern.web import SEARCH

# The pattern.web module has a SearchEngine class,
# with a SearchEngine.search() method that yields a list of Result objects.
# Each Result has url, title, text, language, author and date and properties.
# Subclasses of SearchEngine include: 
# Google, Bing, Yahoo, Twitter, Facebook, Wikipedia, Wiktionary, Flickr, ...

# This example retrieves results from Google based on a given query.
# The Google search engine can handle SEARCH type searches.
# Other search engines may also handle IMAGE, NEWS, ...

# Google's "Custom Search API" is a paid service.
# The pattern.web module uses a test account by default,
# with a 100 free queries per day shared by all Pattern users.
# If this limit is exceeded, SearchEngineLimitError is raised.
# You should obtain your own license key at: 
# https://code.google.com/apis/console/
# Activate "Custom Search API" under "Services" and get the key under "API Access".
# Then use Google(license=[YOUR_KEY]).search().
# This will give you 100 personal free queries, or 5$ per 1000 queries.
engine = Google(license=None, language="en")

# Veale & Hao's method for finding similes using wildcards (*):
# http://afflatus.ucd.ie/Papers/LearningFigurative_CogSci07.pdf
# This will match results such as:
# - "as light as a feather",
# - "as cute as a cupcake",
# - "as drunk as a lord",
# - "as snug as a bug", etc.
q = "as * as a *"

# Google is very fast but you can only get up to 100 (10x10) results per query.
for i in range(1, 2):
    for result in engine.search(q, start=i, count=10, type=SEARCH, cached=True):
        print plaintext(result.text) # plaintext() removes all HTML formatting.
        print result.url
        print result.date
        print
# Out:
# AS similes such as 'as big as a bus'. Vocabulary for ESL ...
# https://www.englishclub.com/vocabulary/figures-similes-list.htm
#
#
# A $100 million 10-year investment in conjunction with e-commerce giant Alibaba
# will establish men's and women's leagues as well as a sevens programme.
# http://en.as.com/
#
#
# Film speed is the measure of a photographic film's sensitivity to light, determined
# by ...... as well as a user-adjustable SOS value. In all cases, the camera should ...
# https://en.wikipedia.org/wiki/Film_speed
#
#
# ... While renewable energy is extremely popular among the German public, power
# lines are not.
# http://www.nytimes.com/2015/12/08/business/energy-environment/change-isnt-as-easy-as-a-flip-of-a-switch.html
# Dec 7, 2015
#
# Asafoetida /æsəˈfɛtᵻdə/ is the dried latex (gum oleoresin) exuded from the
# rhizome or tap root ..... foetida, F. narthex, F. rubricaulis (Hing; Devil's Dung;
# Asafoetida) as well as a discussion of health benefits and usage in clinical
# practice.
# https://en.wikipedia.org/wiki/Asafoetida
#
#
# ... Interior designer Nancy J. Ruddy explains why modern kitchens that walk the line
# between upscale and informal cost up to $160000 each.
# http://www.barrons.com/video/kitchens-that-cost-as-much-as-a-house/610752C2-11F2-403D-97CA-8CE76EEBA2CE.html
# Sep 2, 2016
#
# Deep Security is available as software, as a service, or from the Marketplaces of
# leading Cloud providers like AWS and Azure. Say NO to ransomware. Over 100 ...
# http://www.trendmicro.com/us/business/saas/deep-security-as-a-service/
#
#
# ... Imagine a spider as big as a child's forearm that weighs as much as a puppy.
# That's how huge the South American Goliath birdeater ...
# http://www.livescience.com/56525-goliath-birdeater-spider-photos.html
# Oct 18, 2016
#
# ... Furthermore, "in a company, it can take anywhere from 3–5 years and sometimes
# as little as a year or less to move a product out," says Steel.
# http://www.sciencemag.org/careers/features/2015/10/industry-experience-platform-academic-careers
# Oct 9, 2015
#
# Thus, the second sentence of paragraph (a)(1) authorizes the court to consider a
# motion for judgment as a matter of law as soon as a party has completed a ...
# https://www.law.cornell.edu/rules/frcp/rule_50

# %% [markdown]
# Google translate...
# HTTP401Authentication: Google translate API is a paid service

# %% [markdown]
# Crawler is nice. combine with html parsing stuff

# %%
import os, sys

from pattern.web import Crawler, DEPTH, BREADTH, FIFO, LIFO

# This example demonstrates how to use the Crawler class for web crawling.

# -------------------------------------------------------------------------------------------------
# First, we need a subclass of Crawler with its own Crawler.visit() method.
# The visit() method takes two parameters: the visited link and the HTML source.
# We could parse the HTML DOM to extract information we need, for example.
# Anything that is not HTML (e.g., a JPEG file) is passed to Crawler.fail().

class SimpleCrawler1(Crawler):
    
    def visit(self, link, source=None):
        print "visiting:", link.url, "from:", link.referrer
        
    def fail(self, link):
        print "failed:", link.url

# Create a new crawler.
# 1) The links parameter is a list of URL's to visit.
#    The crawler will visit the first link, extract new links from the HTML, and queue these for a visit too.
# 2) The domains parameter is a list of allowed domains.
#    The crawler will never leave these domains.
# 3) The delay parameter specifies a number of seconds to wait before revisiting the same domain.
#    In the meantime, other queued links will be crawled if possible.

crawler1 = SimpleCrawler1(links=["http://www.clips.ua.ac.be/pages/pattern/"], domains=["ua.ac.be"], delay=0.0)

print "CRAWLER 1 " + "-" * 50
while len(crawler1.visited) < 5: # Crawler.visited is a dictionary of all URL's visited so far.
    # The Crawler.crawl() method has the same optional parameters as URL.download(),
    # for example: cached=True, proxy=("proxy.com", "https"), ...
    crawler1.crawl(cached=False)

# -------------------------------------------------------------------------------------------------
# Typically, you'll want a crawler that runs in an endless loop as a background process,
# and just keeps on visiting new URL's. In this case, it is rude to use a delay of 0.0,
# because you will keep hammering servers with automated requests.
# A higher delay (in a real-world scenario, say 30 seconds) is better:

crawler2 = SimpleCrawler1(links=["http://www.clips.ua.ac.be/pages/pattern/"], domains=["ua.ac.be"], delay=0.1)

print
print "CRAWLER 2 " + "-" * 50
while True:
    crawler2.crawl(cached=False)
    print "wait..."
    # Of course we don't want this example to run forever,
    # so we still add a stop condition:
    if len(crawler2.visited) > 2:
        break

# -------------------------------------------------------------------------------------------------
# If you create a crawler without a domains=[..] restriction, it is free to roam the entire web.
# What to visit first? You can use Crawler.crawl() with an optional "method" parameter.
# When set to DEPTH, it prefers to visit links in the same domain.
# When set to BREADTH, it prefers to visit links to other domains.
# Observe the difference between crawler3 and crawler4,
# which use DEPTH and BREADTH respectively.

crawler3 = SimpleCrawler1(links=["http://www.clips.ua.ac.be/pages/pattern/"], delay=0.0)

print
print "CRAWLER 3 " + "-" * 50
while len(crawler3.visited) < 3:
    crawler3.crawl(method=DEPTH)
    
crawler4 = SimpleCrawler1(links=["http://www.clips.ua.ac.be/pages/pattern/"], delay=0.0)

print
print "CRAWLER 4 " + "-" * 50
while len(crawler4.visited) < 3:
    crawler4.crawl(method=BREADTH)

# -------------------------------------------------------------------------------------------------
# With Crawler.crawl(method=DEPTH) and a delay,
# the crawler will wait between requests to the same domain.
# In the meantime, it will visit other links.
# Usually this means that it will alternate between a couple of domains:

crawler5 = SimpleCrawler1(links=["http://www.clips.ua.ac.be/pages/pattern/"], delay=0.1)

print
print "CRAWLER 5 " + "-" * 50
while len(crawler5.visited) < 4:
    crawler5.crawl(method=DEPTH)

# -------------------------------------------------------------------------------------------------
# A BREADTH-crawler in an endless crawl loop will eventually queue the entire web for a visit.
# But this is not possible of course: we can't keep the entire web in memory.
# When the number of queued links exceeds Crawler.QUEUE (10,000 by default),
# less relevant queued links will be discarded.
# "Less relevant" depends on two settings:
# 1) First, there is the Crawler.priority() method that returns a number between 0.0-1.0 for a link.
#    Links with a higher priority are more relevant and will be visited sooner.
# 2) Links with an equal priority are queued either FIFO or LIFO.
#    FIFO means first-in-first-out: the earliest queued links will be visited sooner.
#    LIFO means last-in-first-out: more recently queued links will be visited sooner.

class SimpleCrawler2(Crawler):
    
    def visit(self, link, source=None):
        print "visiting:", link.url, "from:", link.referrer
    
    def priority(self, link, method=DEPTH):
        if "?" in link.url:
            # This ignores links with a querystring.
            return 0.0
        else:
            # Otherwise use the default priority ranker,
            # i.e. the priority depends on DEPTH or BREADTH crawl mode.
            return Crawler.priority(self, link, method)

# Note the LIFO sort order. 
# This will make more recently queued links more relevant.
# If you observe the given URL in a browser,
# you'll notice that the last external link at the bottom of the page is now visited first.
crawler6 = SimpleCrawler2(links=["http://www.clips.ua.ac.be/pages/pattern/"], delay=0.1, sort=LIFO)

print
print "CRAWLER 6 " + "-" * 50
while len(crawler6.visited) < 4:
    crawler6.crawl(method=BREADTH)

# -------------------------------------------------------------------------------------------------
# In the long run, the Crawler.visited dictionary will start filling up memory too.
# If you want a single crawler that runs forever, you should empty the dictionary every now and then,
# and instead use a strategy with a persistent database of visited links,
# in combination with Crawler.follow().
# Another strategy would be to use different DEPTH-crawlers for different domains,
# and delete them when they are done.
# Out:
# CRAWLER 1 --------------------------------------------------
# visiting: http://www.clips.ua.ac.be/pages/pattern/ from:
# visiting: http://www.clips.ua.ac.be/pages/pattern#navigation from: http://www.clips.ua.ac.be/pages/pattern/
# visiting: http://www.clips.ua.ac.be/ from: http://www.clips.ua.ac.be/pages/pattern/
# failed: http://www.clips.ua.ac.be/media/pattern-2.6.zip
# failed: http://www.clips.ua.ac.be/media/pattern-2.5.zip
#
# CRAWLER 2 --------------------------------------------------
# visiting: http://www.clips.ua.ac.be/pages/pattern/ from:
# wait...
# visiting: http://www.clips.ua.ac.be/pages/pattern#navigation from: http://www.clips.ua.ac.be/pages/pattern/
# wait...
# visiting: http://www.clips.ua.ac.be/ from: http://www.clips.ua.ac.be/pages/pattern/
# wait...
#
# CRAWLER 3 --------------------------------------------------
# visiting: http://www.clips.ua.ac.be/pages/pattern/ from:
# visiting: http://www.clips.ua.ac.be/pages/pattern#navigation from: http://www.clips.ua.ac.be/pages/pattern/
# visiting: http://www.clips.ua.ac.be/ from: http://www.clips.ua.ac.be/pages/pattern/
#
# CRAWLER 4 --------------------------------------------------
# visiting: http://www.clips.ua.ac.be/pages/pattern/ from:
# visiting: http://www.linfo.org/bsdlicense.html from: http://www.clips.ua.ac.be/pages/pattern/
# visiting: http://twitter.com/share from: http://www.clips.ua.ac.be/pages/pattern/
#
# CRAWLER 5 --------------------------------------------------
# visiting: http://www.clips.ua.ac.be/pages/pattern/ from:
# visiting: http://www.clips.ua.ac.be/pages/pattern#navigation from: http://www.clips.ua.ac.be/pages/pattern/
# visiting: http://www.clips.ua.ac.be/ from: http://www.clips.ua.ac.be/pages/pattern/
# failed: http://www.clips.ua.ac.be/media/pattern-2.6.zip
#
# CRAWLER 6 --------------------------------------------------
# visiting: http://www.clips.ua.ac.be/pages/pattern/ from:
# visiting: http://drupal.org from: http://www.clips.ua.ac.be/pages/pattern/
# visiting: http://buytaert.net from: http://drupal.org
# visiting: http://creativecommons.org/licenses/by-nc-sa/3.0/ from: http://buytaert.net
